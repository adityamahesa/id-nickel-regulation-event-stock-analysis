# %%
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import Markdown as md
from ipynb.fs.full import functions
import pandas as pd

InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
tickers = ['DFAM.JK']
start_date = '2022-12-06'
end_date = '2023-01-19'

result = functions.get_ticker_prices(tickers=tickers, start_date=start_date, end_date=end_date)
result
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Close    Volume
# Date
# 2022-12-06  102.0   2865600
# 2022-12-07   97.0   6235300
# 2022-12-08  102.0   9217000
# 2022-12-09  100.0   3753800
# 2022-12-12  100.0    596400
# 2022-12-13   97.0   4065100
# 2022-12-14   94.0   3040100
# 2022-12-15   93.0   4081700
# 2022-12-16   94.0   2078400
# 2022-12-19   95.0  11709900
# 2022-12-20   95.0   2949200
# 2022-12-21   95.0   1379800
# 2022-12-22   96.0   5115600
# 2022-12-23   94.0   2107200
# 2022-12-26   94.0   1339900
# 2022-12-27   94.0   2718800
# 2022-12-28   97.0   5000000
# 2022-12-29   94.0  21467800
# 2022-12-30   92.0   2665100
# 2023-01-02   90.0   1336900
# 2023-01-03   90.0   2625300
# 2023-01-04   90.0    614100
# 2023-01-05   85.0   1982300
# 2023-01-06   90.0   2509300
# 2023-01-09   89.0   1311900
# 2023-01-10   85.0   2386900
# 2023-01-11   86.0   1094200
# 2023-01-12   86.0    431700
# 2023-01-13   86.0    410300
# ...

# %%
with pd.ExcelWriter('output_sandbox.xlsx') as excel_writer:
    result.to_excel(excel_writer=excel_writer, sheet_name='sandbox')

# %%
import yfinance as yf

imas = yf.Ticker(ticker='IMAS.JK')
imas.get_balance_sheet()
# Out:
#                                                           2021-12-31  \
# OrdinarySharesNumber                                    3994291039.0
# ShareIssued                                             3994291039.0
# NetDebt                                             28632677000000.0
# TotalDebt                                           31633779000000.0
# TangibleBookValue                                    5400486000000.0
# InvestedCapital                                     42593392000000.0
# WorkingCapital                                      -7553594000000.0
# NetTangibleAssets                                    5400486000000.0
# CapitalLeaseObligations                                58604000000.0
# CommonStockEquity                                   11018217000000.0
# TotalCapitalization                                 21740119000000.0
# TotalEquityGrossMinorityInterest                    12846217000000.0
# MinorityInterest                                     1828000000000.0
# ...
